# %%
import re

# Sample NLP text
text = "Hello! My email is ad1445@gmail.com and phone number is 900000. Visit https://example.com"

# 1. Tokenization (word extraction)
tokens = re.findall(r'\b\w+\b', text)

# 2. Extract email
emails = re.findall(r'[a-zA-Z0-9._%+-]+@[a-zA-Z.-]+\.[a-zA-Z]{2,}', text)

# 3. Extract phone numbers
phones = re.findall(r'\b\d{10}\b', text)

# 4. Remove URLs (text cleaning)
clean_text = re.sub(r'https?://\S+', '', text)

# 5. Normalize text (lowercase + remove punctuation & digits)
normalized_text = re.sub(r'[^\w\s]', '', clean_text.lower())
normalized_text = re.sub(r'\d+', '', normalized_text)

# Output
print("Tokens:", tokens)
print("Emails:", emails)
print("Phone Numbers:", phones)
print("Clean Text:", normalized_text)
# Out:
# Tokens: ['Hello', 'My', 'email', 'is', 'ad1445', 'gmail', 'com', 'and', 'phone', 'number', 'is', '900000', 'Visit', 'https', 'example', 'com']
# Emails: ['ad1445@gmail.com']
# Phone Numbers: []
# Clean Text: hello my email is adgmailcom and phone number is  visit

# %%
import re

# Sample NLP text
text = "Hello! My email is ad1445@gmail.com and phone number is 900000. Visit https://example.com"

# 1. Tokenization (word extraction)
tokens = re.findall(r'\b\w+\b', text)

# 2. Extract email
emails = re.findall(r'[a-zA-Z0-9._%+-]+@[a-zA-Z.-]+\.[a-zA-Z]{2,}', text)

# 3. Extract phone numbers
phones = re.findall(r'\b\d{10}\b', text)

# 4. Remove URLs (text cleaning)
clean_text = re.sub(r'https?://\S+', '', text)

# 5. Normalize text (lowercase + remove punctuation & digits)
normalized_text = re.sub(r'[^\w\s]', '', clean_text.lower())
normalized_text = re.sub(r'\d+', '', normalized_text)

# Output
print("Tokens:", tokens)
print("Emails:", emails)
print("Phone Numbers:", phones)
print("Clean Text:", normalized_text)
# Out:
# Tokens: ['Hello', 'My', 'email', 'is', 'ad1445', 'gmail', 'com', 'and', 'phone', 'number', 'is', '900000', 'Visit', 'https', 'example', 'com']
# Emails: ['ad1445@gmail.com']
# Phone Numbers: []
# Clean Text: hello my email is adgmailcom and phone number is  visit

# %%
import re
from collections import Counter

# Large sample text
text = """
Natural Language Processing (NLP) is a branch of Artificial Intelligence.
It enables machines to understand and generate human language.
In modern systems, text data contains punctuation, numbers like 12345,
extra spaces, and multiple sentences that need preprocessing.
In 2024, NLP applications include chatbots, search engines, sentiment analysis,
machine translation, speech recognition, and document summarization.
"""

# -------------------- REGEX PATTERNS --------------------
sentence_pattern = r'[^.!?]+'
token_pattern = r'\b\w+\b'
number_pattern = r'\d+'
punctuation_pattern = r'[^\w\s]'
space_pattern = r'\s+'
keyword_pattern = r'\bnlp\b'

# -------------------- PRINT REGEX PATTERNS --------------------
print("Sentence Regex:", sentence_pattern)
print("Token Regex:", token_pattern)
print("Number Regex:", number_pattern)
print("Punctuation Regex:", punctuation_pattern)
print("Whitespace Regex:", space_pattern)
print("Keyword Regex:", keyword_pattern)

# -------------------- NLP OPERATIONS --------------------

# 1. Sentence extraction
sentences = re.findall(sentence_pattern, text)

# 2. Tokenization
tokens = re.findall(token_pattern, text.lower())

# 3. Remove numbers
text_no_numbers = re.sub(number_pattern, '', text)

# 4. Remove punctuation
text_no_punct = re.sub(punctuation_pattern, '', text_no_numbers)

# 5. Normalize text (lowercase + remove extra spaces)
normalized_text = re.sub(space_pattern, ' ', text_no_punct.lower()).strip()

# 6. Keyword search
keyword_found = bool(re.search(keyword_pattern, normalized_text))

# 7. Remove short words (length ≤ 2)
filtered_tokens = [word for word in tokens if len(word) > 2]

# 8. Word frequency
word_frequency = Counter(filtered_tokens)

# -------------------- OUTPUT --------------------
print("\nNumber of Sentences:", len(sentences))
print("Total Tokens:", len(tokens))
print("Normalized Text:", normalized_text)
print("Keyword 'nlp' Found:", keyword_found)
print("Top 5 Most Common Words:", word_frequency.most_common(5))
# Out:
# Sentence Regex: [^.!?]+
# Token Regex: \b\w+\b
# Number Regex: \d+
# Punctuation Regex: [^\w\s]
# Whitespace Regex: \s+
# Keyword Regex: \bnlp\b
#
# Number of Sentences: 5
# Total Tokens: 54
# Normalized Text: natural language processing nlp is a branch of artificial intelligence it enables machines to understand and generate human language in modern systems text data contains punctuation numbers like extra spaces and multiple sentences that need preprocessing in nlp applications include chatbots search engines sentiment analysis machine translation speech recognition and document summarization
# Keyword 'nlp' Found: True
# Top 5 Most Common Words: [('and', 3), ('language', 2), ('nlp', 2), ('natural', 1), ('processing', 1)]

# %%
from nltk import Tree

# Parse Tree 1: PP attached to the VERB (instrument interpretation)
tree1 = Tree('S', [
    Tree('NP', ['I']),
    Tree('VP', [
        'saw',
        Tree('NP', ['the', 'man']),
        Tree('PP', [
            'with',
            Tree('NP', ['the', 'telescope'])
        ])
    ])
])

# Parse Tree 2: PP attached to the NOUN (modifier interpretation)
tree2 = Tree('S', [
    Tree('NP', ['I']),
    Tree('VP', [
        'saw',
        Tree('NP', [
            'the',
            'man',
            Tree('PP', [
                'with',
                Tree('NP', ['the', 'telescope'])
            ])
        ])
    ])
])

print("Parse Tree 1: PP attached to Verb")
tree1.pretty_print()

print("\nParse Tree 2: PP attached to Noun")
tree2.pretty_print()
# Out:
# Parse Tree 1: PP attached to Verb
#      S
#   ___|___________
#  |               VP
#  |    ___________|________
#  |   |       |            PP
#  |   |       |        ____|___
#  NP  |       NP      |        NP
#  |   |    ___|___    |     ___|______
#  I  saw the     man with the     telescope
#
#
# Parse Tree 2: PP attached to Noun
#      S
#   ___|_______
#  |           VP
#  |    _______|___
#  |   |           NP
#  |   |    _______|____
#  |   |   |   |        PP
#  |   |   |   |    ____|___
#  NP  |   |   |   |        NP
#  |   |   |   |   |     ___|______
#  I  saw the man with the     telescope

# %%
from nltk import Tree

# Parse Tree 1: Prepositional Phrase attached to the Verb Phrase
tree1 = Tree('Sentence', [
    Tree('Noun_Phrase', ['I']),
    Tree('Verb_Phrase', [
        'saw',
        Tree('Noun_Phrase', ['the', 'man']),
        Tree('Prepositional_Phrase', [
            'with',
            Tree('Noun_Phrase', ['the', 'telescope'])
        ])
    ])
])

# Parse Tree 2: Prepositional Phrase attached to the Noun Phrase
tree2 = Tree('Sentence', [
    Tree('Noun_Phrase', ['I']),
    Tree('Verb_Phrase', [
        'saw',
        Tree('Noun_Phrase', [
            'the',
            'man',
            Tree('Prepositional_Phrase', [
                'with',
                Tree('Noun_Phrase', ['the', 'telescope'])
            ])
        ])
    ])
])

print("Parse Tree 1: Prepositional Phrase attached to Verb Phrase")
tree1.pretty_print()

print("\nParse Tree 2: Prepositional Phrase attached to Noun Phrase")
tree2.pretty_print()
# Out:
# Parse Tree 1: Prepositional Phrase attached to Verb Phrase
#             Sentence
#       _________|__________________________
#      |                               Verb_Phrase
#      |          __________________________|__________________
#      |         |              |                       Prepositional_Ph
#      |         |              |                             rase
#      |         |              |                    __________|______________
# Noun_Phrase    |         Noun_Phrase              |                    Noun_Phrase
#      |         |       _______|___________        |           ______________|__________
#      I        saw    the                 man     with       the                    telescope
#
#
# Parse Tree 2: Prepositional Phrase attached to Noun Phrase
#             Sentence
#       _________|______________
#      |                   Verb_Phrase
#      |          ______________|___________
#      |         |                     Noun_Phrase
#      |         |       ___________________|_____________
#      |         |      |       |                  Prepositional_Ph
#      |         |      |       |                        rase
#      |         |      |       |            _____________|______________
# Noun_Phrase    |      |       |           |                       Noun_Phrase
#      |         |      |       |           |              ______________|__________
#      I        saw    the     man         with          the                    telescope

# %%
import nltk
from nltk import CFG
from nltk.parse import RecursiveDescentParser, ChartParser

# Define a simple grammar
grammar = CFG.fromstring("""
Sentence -> Noun_Phrase Verb_Phrase
Noun_Phrase -> 'I' | 'the' 'man'
Verb_Phrase -> 'saw' Noun_Phrase
""")

sentence = "I saw the man".split()

# ---------- Top-Down Parsing ----------
print("Top-Down Parsing:")
top_down = RecursiveDescentParser(grammar)

for tree in top_down.parse(sentence):
    tree.pretty_print()

# ---------- Bottom-Up Parsing ----------
print("\nBottom-Up Parsing:")
bottom_up = ChartParser(grammar)

for tree in bottom_up.parse(sentence):
    tree.pretty_print()
# Out:
# Top-Down Parsing:
#                 Sentence
#       _____________|__________
#      |                   Verb_Phrase
#      |        ________________|___________
# Noun_Phrase  |                       Noun_Phrase
#      |       |                 ___________|_______
#      I      saw              the                 man
#
#
# Bottom-Up Parsing:
#                 Sentence
#       _____________|__________
#      |                   Verb_Phrase
#      |        ________________|___________
# Noun_Phrase  |                       Noun_Phrase
#      |       |                 ___________|_______
#      I      saw              the                 man

# %%
import re

# Sample text for demonstrations
text_literal = "Hello world, hello Python, hello regex!"
text_chars = "The price is $12.99, quantity: 100. Text with spaces and_underscores."

# 1. Demonstrate literal matching
print("--- Literal Matching ---")
pattern_literal = "hello"
matches_literal = re.findall(pattern_literal, text_literal)
print(f"Pattern: '{pattern_literal}', Text: '{text_literal}'")
print(f"Matches: {matches_literal}\n")

# 2. Demonstrate character classes
print("--- Character Class: \\d (digits) ---")
matches_d = re.findall(r'\d', text_chars)
print(f"Pattern: '\\d', Text: '{text_chars}'")
print(f"Matches (\\d): {matches_d}\n")

print("--- Character Class: \\D (non-digits) ---")
matches_D = re.findall(r'\D', text_chars)
print(f"Pattern: '\\D', Text: '{text_chars}'")
print(f"Matches (\\D): {matches_D}\n")

print("--- Character Class: \\w (word characters) ---")
matches_w = re.findall(r'\w', text_chars)
print(f"Pattern: '\\w', Text: '{text_chars}'")
print(f"Matches (\\w): {matches_w}\n")

print("--- Character Class: \\W (non-word characters) ---")
matches_W = re.findall(r'\W', text_chars)
print(f"Pattern: '\\W', Text: '{text_chars}'")
print(f"Matches (\\W): {matches_W}\n")

print("--- Character Class: \\s (whitespace) ---")
matches_s = re.findall(r'\s', text_chars)
print(f"Pattern: '\\s', Text: '{text_chars}'")
print(f"Matches (\\s): {matches_s}\n")

print("--- Character Class: \\S (non-whitespace) ---")
matches_S = re.findall(r'\S', text_chars)
print(f"Pattern: '\\S', Text: '{text_chars}'")
print(f"Matches (\\S): {matches_S}\n")
# Out:
# --- Literal Matching ---
# Pattern: 'hello', Text: 'Hello world, hello Python, hello regex!'
# Matches: ['hello', 'hello']
#
# --- Character Class: \d (digits) ---
# Pattern: '\d', Text: 'The price is $12.99, quantity: 100. Text with spaces and_underscores.'
# Matches (\d): ['1', '2', '9', '9', '1', '0', '0']
#
# --- Character Class: \D (non-digits) ---
# Pattern: '\D', Text: 'The price is $12.99, quantity: 100. Text with spaces and_underscores.'
# Matches (\D): ['T', 'h', 'e', ' ', 'p', 'r', 'i', 'c', 'e', ' ', 'i', 's', ' ', '$', '.', ',', ' ', 'q', 'u', 'a', 'n', 't', 'i', 't', 'y', ':', ' ', '.', ' ', 'T', 'e', 'x', 't', ' ', 'w', 'i', 't', 'h', ' ', 's', 'p', 'a', 'c', 'e', 's', ' ', 'a', 'n', 'd', '_', 'u', 'n', 'd', 'e', 'r', 's', 'c', 'o', 'r', 'e', 's', '.']
#
# --- Character Class: \w (word characters) ---
# Pattern: '\w', Text: 'The price is $12.99, quantity: 100. Text with spaces and_underscores.'
# Matches (\w): ['T', 'h', 'e', 'p', 'r', 'i', 'c', 'e', 'i', 's', '1', '2', '9', '9', 'q', 'u', 'a', 'n', 't', 'i', 't', 'y', '1', '0', '0', 'T', 'e', 'x', 't', 'w', 'i', 't', 'h', 's', 'p', 'a', 'c', 'e', 's', 'a', 'n', 'd', '_', 'u', 'n', 'd', 'e', 'r', 's', 'c', 'o', 'r', 'e', 's']
#
# --- Character Class: \W (non-word characters) ---
# Pattern: '\W', Text: 'The price is $12.99, quantity: 100. Text with spaces and_underscores.'
# Matches (\W): [' ', ' ', ' ', '$', '.', ',', ' ', ':', ' ', '.', ' ', ' ', ' ', ' ', '.']
#
# --- Character Class: \s (whitespace) ---
# Pattern: '\s', Text: 'The price is $12.99, quantity: 100. Text with spaces and_underscores.'
# Matches (\s): [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
#
# --- Character Class: \S (non-whitespace) ---
# Pattern: '\S', Text: 'The price is $12.99, quantity: 100. Text with spaces and_underscores.'
# Matches (\S): ['T', 'h', 'e', 'p', 'r', 'i', 'c', 'e', 'i', 's', '$', '1', '2', '.', '9', '9', ',', 'q', 'u', 'a', 'n', 't', 'i', 't', 'y', ':', '1', '0', '0', '.', 'T', 'e', 'x', 't', 'w', 'i', 't', 'h', 's', 'p', 'a', 'c', 'e', 's', 'a', 'n', 'd', '_', 'u', 'n', 'd', 'e', 'r', 's', 'c', 'o', 'r', 'e', 's', '.']
